# %%
#Importação das bibliotecas


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importação dos datasets
heart_disease_df_cleveland = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data')
heart_disease_df_switzerland = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.switzerland.data')
heart_disease_df_hungarian = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data')
heart_disease_df_va = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.va.data')
#heart_disease_df_cleveland.head()
#heart_disease_df_switzerland.head()
#heart_disease_df_hungarian.head()
#heart_disease_df_va.head()

# %% [markdown]
# # **Legenda do dataset**
# ----------------------------------------------------------------
# idade: idade em anos
#
# sex: sex (1 = male; 0 = female)
#
# cp: tipo de dor no peito
# - Valor 1: angina típica
# - Valor 2: angina atípica
# - Valor 3: dor não anginosa
# - Valor 4: assintomático
#
# trestbps: pressão arterial em repouso (em mm Hg na admissão ao hospital)
#
# chol: colesterol sérico em mg / dl
#
# fbs: (açúcar no sangue em jejum> 120 mg / dl) (1 = verdadeiro; 0 = falso)
#
# thalach: frequência cardíaca máxima alcançada
#
# restbpd: pressão arterial em repouso
#
#
# exang: angina induzida por exercício (1 = sim; 0 = não)
#
# oldpeak:depressão de ST induzida por exercício em relação ao repouso
#
# slope:a inclinação do segmento ST de pico do exercício
# - Valor 1: inclinação ascendente
# - Valor 2: plano
# - Valor 3: declive
#
# ca: número de vasos principais (0-3) coloridos por fluorosopia
#
# thal:frequência cardíaca normal ou se possue ou já possuiram arritmia
#
#  3 = normal; 6 = defeito corrigido; 7 = defeito reversível
#
# target = 1 o indivíduo sofre de  doença cardíaca
#
#
# target = 0 o indivíduo não de doença cardíaca
#
# ---------------------------------------------------------------------
# Referências
#
# <https://archive.ics.uci.edu/ml/datasets/Heart+Disease>
#
# <https://towardsdatascience.com/heart-disease-prediction-73468d630cfc>

# %% [markdown]
#                                        Introdução
#
# De acordo com OMS a doença cardíaca é a principal causa de morte no mundo por mais de 20 anos. Os pesquisadores estimam que só no ano 2019 foram  9 milhões  representando 16% do total de mortes por todas as causas.
#
#                                         Glossario
#
# *Pressão Arterial (trestbps e restbpd)*
#
#  * A pressão arterial é a pressão exercida pelo sangue dentro dos vasos sanguíneos, com a força proveniente dos batimentos cardíacos (bombeamento por meio do coração). Quanto mais sangue for bombeado do coração por minuto, maior será esse valor, que tem dois números: um máximo, ou sistólico, e um mínimo, ou diastólico.
#
#  A pressão não é fixa e pode variar instantaneamente, dependendo do estado da pessoa no momento (Pertubações emocionais e maus hábitos alimentares pode influênciar no resultado ). A pressão diastólica representa aquela detectada no *repouso* muscular do coração entre duas batidas e tem um valor, quase sempre, menor. Espera-se que a pressão arterial de um adulto saudável em repouso seja de 120 mmHg na sístole e 80 mmHg na diástole. Popularmente, esses valores são expressos como 120/80 ou 12 por 8.
#
# *Colesterol Sérico (chol)*
# * O colesterol é um tipo de gordura encontrada em nosso organismo importante para o seu funcionamento normal. O colesterol é o componente estrutural das membranas celulares em nosso corpo e está presente no coração, cérebro, fígado, intestinos, músculos, nervos e pele. Nosso corpo usa o colesterol para produzir alguns hormônios, tais como vitamina D, testosterona, estrógeno, cortisol e ácidos biliares que ajudam na digestão das gorduras.
#
#  Aproximadamente 70% do colesterol é produzido pelo nosso próprio organismo, no fígado, enquanto que os outros 30% são provenientes da dieta. Contudo, ao consumir grandes quantidades de alimentos ricos em gordura, o fígado acaba produzindo mais colesterol do que o normal. Tanto as taxas de colesterol muito altas quanto as muito baixas são perigosas à saúde.
#
#  Já o colesterol sérico ou  colesterol total é a soma das várias frações de colesterol, ou seja, a união do colesterol LDL, HDL e VLDL
#
# *Colesterol LDL*
# * O colesterol LDL é uma lipoproteína de baixa densidade, conhecido popularmente como colesterol “ruim”. Essa fração do colesterol total se acumula nas paredes das artérias sanguíneas, e quando seus níveis estão elevados também aumenta o risco de desenvolver doenças coronárias, como por exemplo: insuficiência arterial, infarto do miocárdio ou derrame cerebral. Os níveis adequados do colesterol LDL em pessoas saudáveis deverão estar abaixo dos 130 mg/dL sangue e para as pessoas que apresentam algum quadro de risco os níveis não deverão ultrapassar os 70 mg/dL.
#
# *Colesterol HDL*
# * O colesterol HDL é uma lipoproteína de alta densidade, conhecido popularmente como colesterol “bom” que nos protege do LDL (colesterol “ruim”). Essa fração do colesterol total possui como principal função extrair o colesterol LDL das artérias e lavá-lo até o fígado onde ele será quebrado e excretado posteriormente. Por isso, quanto maiores forem os níveis de HDL, menor será o risco de contrair doenças cardiovasculares. Os níveis adequados de colesterol HDL devem ser superiores a 40 mg/dL de sangue.
#
#  *Colesterol VLDL*
# * O Colesterol VLDL é uma lipoproteínas de muita baixa densidade, produzido no fígado e tem como sua principal função transportar os triglicerídeos pela corrente sanguínea.Essa fração do colesterol total está diretamente ligado à quantidade de triglicérides e os seus níveis são diretamente influenciados pela dieta que fazemos.Os valores considerados normais devem ser estar em torno de 200mg/dL; Ligeiramente altos quando estão entre 200 e 239 mg/dL e altos quando estão acima de 240 mg/dL.
#
#  *Frequência Cardíaca (thalach)*
# * frequência cardíaca é o número de pulsação do coração pela unidade de tempo expressada geralmente como batidas pela acta (BPM), ou seja,  A frequência cardíaca indica a quantidade de vezes que o coração bate por minuto, o seu valor normal, em adultos, varia entre 60 e 100 batimentos por minuto em repouso. Porém, a frequência considerada normal tende a variar de acordo com alguns fatores, como a idade, o nível de atividade física ou a presença de alguma doença cardíaca. Já a frequência cardíaca máxima é o número máximo de batimentos cardíacos que ocorre no espaço de 1 minuto durante algum esforço
#
# * Obs: O dataset não especifica qual tipo de defeito ou altereção que ele descreve no atributo (thal) mas depois de pesquisas, cremos a levar que se tratar de arritmia cardíaca, sendo o parâmentro normal se tratar da ausência de arritmia, o defeito corrigido especifica que o paciente já teve arritimia e foi curada e o defeito reversível é que o paciente ainda está em tratamento
#
#  *Arritmia Cardíaca (thal)*
#
# * Arritmia é uma alteração nos batimentos cardíacos. Um coração sadio bate entre 60 e 100 vezes por minuto. O aumento desse número é chamado de taquicardia; sua diminuição, bradicardia.
#
#
#  *Angina (cp e exang)*
# * O termo angina caracteriza “dor” e seu uso mais rotineiro na prática médica diz respeito a dor ou desconforto torácico.
# Alguns pacientes sentem a angina (dor no peito) sempre que o coração trabalha mais forte (atividades físicas, emoção, baixas temperaturas), de forma que, com o tempo e a frequência do evento, ela passa a ser até previsível. Tem durabilidade curta, de até 10 minutos e melhora espontaneamente quando o fator desencadeador é cessado. Este tipo de dor torácica é denominada como angina estável ela e aumenta a probabilidade de um ataque cardíaco no futuro.
# Em outros casos, quando a dor iniciou com atividade física de menor intensidade do que antes (até mesmo em repouso), tem duração mais longa de cerca de 20 minutos e não tem melhora com o afastamento do fator causal e mesmo com uso de algumas medicações, denominamos de angina instável.
#
#  *Angina tipica*
#
# * Também chamada de angina de peito ou angina pectoris, é um tipo de dor no peito de origem isquêmica que surge quando o miocárdio (músculo do coração) recebe menos sangue que o necessário para o seu normal funcionamento.
#
# *Isquemia*
#
# * É um termo médico que indica um suprimento inadequado de sangue para determinado tecido. A isquemia pode surgir em qualquer área do corpo: pele, membros, olhos, intestinos, cérebro, rins, fígado, etc. Um tecido ou órgão isquêmico é aquele cujas células estão recebendo menos sangue e oxigênio que o necessário para o seu funcionamento normal.
#
#  *Angina atipica*
#
# * A angina de Prinzmetal, também chamada de angina variante, é uma forma atípica de dor no peito que ocorre em cerca de 2% dos pacientes com isquemia cardíaca. Nesses casos, não há obstrução mecânica das coronárias, mas sim episódios súbitos de espasmos da artéria, que provocam redução aguda do fluxo sanguíneo para o miocárdio com duração média de 2 a 5 minutos
#
#  *Glicose (açúcar) no sangue (fbs)*
#
# * A glicose é um carboidrato considerado uma das principais fontes de energia. O pâncreas é o órgão responsável em produzir o hormônio denominado insulina, e que é o responsável por permitir a entrada da glicose em nossas células. Quando o pâncreas está comprometido, ocorre uma deficiência na produção de insulina o que altera a captação da glicose pelas células resultando no aumento da glicose no sangue.
#
#  * Relação com doencas cardíaca
#
#  A insuficiência cardíaca (IC) é uma doença geralmente causada por um dano no coração, em consequência de outra doença. O coração danificado perde a capacidade de bombear o sangue pelo corpo de forma suficiente para suprir nossas necessidades de oxigênio e nutrientes. É fácil imaginar que doenças cardíacas como infarto ou hipertensão podem ‘machucar’ o coração ao longo do tempo, mas você sabia que o diabetes é também uma das principais causas da IC.
# Apesar de não ser uma doença cardíaca, com o passar do tempo, o diabetes sem controle adequado leva a um excesso de açúcar (glicose) circulando no nosso sangue, danificando os vasos sanguíneos e até o coração. E apesar de nem todas as pessoas com diabetes saberem disso, elas têm até oito vezes mais chances de desenvolver uma doença cardíaca do que a população em geral. Além disso, infelizmente, mais da metade dos pacientes já têm complicações cardíacas quando são diagnosticados com diabetes tipo 2
#
# *Segmento St*
#
# * Segmento que, no eletrocardiograma, fica compreendido entre o fim do complexo QRS e o começo da onda T. O segmento S T corresponde ao intervalo entre o fim da despolarização e o início da repolarização ventricular.
# *Eletrocardiograma*
# O Eletrocardiograma também é chamado de ECG ou eletrocardiografia. É um exame que avalia a atividade elétrica do coração por meio de eletrodos fixados na pele. Através desse exame, é possível detectar o ritmo do coração e o número de batimentos por minuto.
#
# * Tipos
#
#  <https://lh3.googleusercontent.com/proxy?Vl0pS5h216A9Uv6SuxiL-ZJSRlM5uB7TWF0KtAVXtvvJw9GZe9u4Wnhi9Q9AulEDXfWTrJgM6nVsSXeoBxaQnZsolV2hTDMdwwO6w1oC06RKPldWLu5nK6Fr6grlY7f5lLFM1KRSHVtkLketJlprb7wB>
#
#
#
# *Vasos Principais*
#  Os grandes vasos do coração são: a aorta, a artéria pulmonar, a veia pulmonar e as veias cavas superior e inferior. ]
#
# *Fluoroscopia*
# * A fluoroscopia é uma técnica de imagem comumente utilizada na medicina para obter imagens em tempo real em movimento das estruturas internas de um paciente através do uso de um Fluoroscópio
#
#  ------------------------------------------------------------------------------
#
#
# * Referências
#
#  <https://www.tuasaude.com/frequencia-cardiaca/>
#
#  <https://www.ladoaladopelavida.org.br/angina-o-que-e-doencas-cardiovasculares>
#
#  <https://www.minhavida.com.br/saude/temas/angina>
#
#  <https://www.mdsaude.com/cardiologia/angina/>
#
#  <https://www.infopedia.pt/dicionarios/termos-medicos/segmento+S+T#:~:text=Segmento%20que%2C%20no%20eletrocardiograma%2C%20fica,o%20início%20da%20repolarização%20ventricular.>
#
#  <https://saude.novartis.com.br/insuficiencia-cardiaca/diabetes-e-insuficiencia-cardiaca-entenda-a-relacao/#:~:text=Apesar%20de%20n%C3%A3o%20ser%20uma,sangu%C3%ADneos%20e%20at%C3%A9%20o%20cora%C3%A7%C3%A3o.>
#
#  <https://www.hospitalviladaserra.com.br/o-que-e-glicose-e-por-que-ela-aumenta/>
#
#  <http://hermespardini.com.br/blog/?p=76#:~:text=O%20colesterol%20total%20%C3%A9%20a,e%20triglic%C3%A9rides%20na%20corrente%20sangu%C3%ADnea.>
#
#  <http://g1.globo.com/bemestar/noticia/2011/03/entenda-o-que-e-pressao-arterial-os-fatores-de-risco-e-recomendacoes.html#:~:text=A%20press%C3%A3o%20arterial%20%C3%A9%20a,e%20um%20m%C3%ADnimo%2C%20ou%20diast%C3%B3lico.>
#
#  <https://www.kenhub.com/pt/library/anatomia/coracao>

# %% [markdown]
# *Justificativas*
# * Obs: O dataset estava com apresentando alguns erros, desta forma a equipe, por meio de um concenso, decidiu como proceder diante dessa dificuldade.
#
#
#                                      Cleveland
#
# *  Esse foi o dataset mais completo, os únicos ponto a sinalizar foram que  faltaram 2% dados em (THAl) e 4 dados em (CA)
#
#
#                                        Suiça
#
# *  Nesse dataset eram apresentados dois tipos de erros: o primeiro foi o atributo (CHOL), que estava zerado, no entanto como ele não iria influenciar na análise, foi decidido o drop desse atributo, já o sengundo erro foi a falta de dados em alguns atributos, de maneira a deixar as análises mais uniformes, foi determinado que atributos com menos de 50% dos dados seriam retirados para evitar de enviesar a I.A, então seguindo a regra os atributos (FBS) e (CA) foram retirados por ambos apresentavam respectivamente apenas 40% e 5%  dos seus dados,e somente (TRESTBPS) foi mantido por não apresentar 2% dos seus dados.
#
#
#                                      Hungria
#
# *  Esse dataset não  apresentava dados em alguns atributos,então seguindo a regra os atributos (CHOL) e (FBS) foram mantidos por ambos apresentarem respectivamente apenas 93% e 97%  dos seus dados, (SPOLE) ,(CA) e (THAL) foram retirados por não apresentarem mais de 50 % dos seus dados, sendo respectivamente 64%,98% e 98% de dados faltantes.
#
#
#                                       Califónia
#
# *   Nesse dataset  faltam alguns dados,então seguindo a regra os atributos (CHOL),(FBS),(THALAC),(EXANG), (OLDPEAK) e (TRESTBHS) foram mantidos por apresentarem respectivamente 3%,3%,26%,26%,28%  e 28%, (SPOLE) ,(CA) e (THAL) foram retirados por não apresentarem mais de 50 % dos seus dados sendo respectivamente 51%,99% e 82% de dados faltantes.

# %%
#Renomeando o nome das colunas do dataset "heart_disease_df_cleveland"

heart_disease_df_cleveland.rename(columns={'63.0':'age','1.0':'sex','1.0.1':'cp','145.0':'trestbps','233.0':'chol','1.0.2':'fbs','2.0':'restecg','150.0':'thalach','0.0':'exang','2.3':'oldpeak','3.0':'slope','0.0.1':'ca','6.0':'thal','0':'target'},inplace=True)

# %%
##Renomeando o nome das colunas do dataset "heart_disease_df_switzerland"

heart_disease_df_switzerland.rename(columns={'32':'age','1':'sex','1.1':'cp','95':'trestbps','0':'chol','?':'fbs','0.1':'restecg','127':'thalach','0.2':'exang','.7':'oldpeak','1.2':'slope','?.1':'ca','?.2':'thal','1.3':'target'},inplace=True)

# %%
#Renomeando o nome das colunas do dataset "heart_disease_df_hungarian"

heart_disease_df_hungarian.rename(columns={'28':'age','1':'sex','2':'cp','130':'trestbps','132':'chol','0':'fbs','2.1':'restecg','185':'thalach','0.1':'exang','0.2':'oldpeak','?':'slope','?.1':'ca','?.2':'thal','0.3':'target'},inplace=True)

# %%
#Renomeando o nome das colunas do dataset "heart_disease_df_va"

heart_disease_df_va.rename(columns={'63':'age','1':'sex','4':'cp','140':'trestbps','260':'chol','0':'fbs','1.1':'restecg','112':'thalach','1.2':'exang','3':'oldpeak','2':'slope','?':'ca','?.1':'thal','2.1':'target'},inplace=True)

# %% [markdown]
# # **Análise exploratória dos dados de Cleveland**

# %%
#Utlizindo a função head() para que assim retorne as 5 primeiras linhas do dataset e mostre os seus dados.
heart_disease_df_cleveland.head()
# Out:
#     age  sex   cp  trestbps   chol  ...  oldpeak  slope   ca  thal  target
# 0  67.0  1.0  4.0     160.0  286.0  ...      1.5    2.0  3.0   3.0       2
# 1  67.0  1.0  4.0     120.0  229.0  ...      2.6    2.0  2.0   7.0       1
# 2  37.0  1.0  3.0     130.0  250.0  ...      3.5    3.0  0.0   3.0       0
# 3  41.0  0.0  2.0     130.0  204.0  ...      1.4    1.0  0.0   3.0       0
# 4  56.0  1.0  2.0     120.0  236.0  ...      0.8    1.0  0.0   3.0       0
#
# [5 rows x 14 columns]

# %%
#Normalização das tabelas

heart_disease_df_cleveland['age'] = heart_disease_df_cleveland['age'].apply(lambda x: None if x == '?' else x) 
heart_disease_df_cleveland['sex'] = heart_disease_df_cleveland['sex'].apply(lambda x: None if x == '?' else x)
heart_disease_df_cleveland['cp'] = heart_disease_df_cleveland['cp'].apply(lambda x: None if x == '?' else x)
heart_disease_df_cleveland['trestbps'] = heart_disease_df_cleveland['trestbps'].apply(lambda x: None if x == '?' else x)
heart_disease_df_cleveland['fbs'] = heart_disease_df_cleveland['fbs'].apply(lambda x: None if x == '?' else x)
heart_disease_df_cleveland['restecg'] = heart_disease_df_cleveland['restecg'].apply(lambda x: None if x == '?' else x) 
heart_disease_df_cleveland['thalach'] = heart_disease_df_cleveland['thalach'].apply(lambda x: None if x == '?' else x)
heart_disease_df_cleveland['exang'] = heart_disease_df_cleveland['exang'].apply(lambda x: None if x == '?' else x)
heart_disease_df_cleveland['oldpeak'] = heart_disease_df_cleveland['oldpeak'].apply(lambda x: None if x == '?' else x)
heart_disease_df_cleveland['slope'] = heart_disease_df_cleveland['slope'].apply(lambda x: None if x == '?' else x)
heart_disease_df_cleveland['ca'] = heart_disease_df_cleveland['ca'].apply(lambda x: None if x == '?' else x)
heart_disease_df_cleveland['thal'] = heart_disease_df_cleveland['thal'].apply(lambda x: None if x == '?' else x)
heart_disease_df_cleveland['target'] = heart_disease_df_cleveland['target'].apply(lambda x: None if x == '?' else x)

# %%
#Utilização do comando "astype" para pegar o determinado valor e converter ele.

heart_disease_df_cleveland['age']= heart_disease_df_cleveland['age'].astype(int)
heart_disease_df_cleveland['sex']= heart_disease_df_cleveland['sex'].astype(int)

# %%
 heart_disease_df_cleveland['target'] =  heart_disease_df_cleveland.target.replace([1,2,3,4],['yes','yes','yes','yes'])
 heart_disease_df_cleveland['target'] =  heart_disease_df_cleveland.target.replace([0],['no'])

# %%
heart_disease_df_cleveland['sex'] =  heart_disease_df_cleveland.sex.replace([0.,1],['female','male'])

# %%
#Apresentando os dados com os alguns valores deles convertidos

heart_disease_df_cleveland.head()
# Out:
#    age     sex   cp  trestbps   chol  ...  oldpeak  slope   ca  thal  target
# 0   67    male  4.0     160.0  286.0  ...      1.5    2.0  3.0   3.0     yes
# 1   67    male  4.0     120.0  229.0  ...      2.6    2.0  2.0   7.0     yes
# 2   37    male  3.0     130.0  250.0  ...      3.5    3.0  0.0   3.0      no
# 3   41  female  2.0     130.0  204.0  ...      1.4    1.0  0.0   3.0      no
# 4   56    male  2.0     120.0  236.0  ...      0.8    1.0  0.0   3.0      no
#
# [5 rows x 14 columns]

# %%
#Utilizando a função info(), para que assim demonstre uma visão geral do nosso dataset

heart_disease_df_cleveland.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       302 non-null    int64
#  1   sex       302 non-null    object
#  2   cp        302 non-null    float64
#  3   trestbps  302 non-null    float64
#  4   chol      302 non-null    float64
#  5   fbs       302 non-null    float64
#  6   restecg   302 non-null    float64
#  7   thalach   302 non-null    float64
#  8   exang     302 non-null    float64
#  9   oldpeak   302 non-null    float64
#  10  slope     302 non-null    float64
#  11  ca        298 non-null    object
#  12  thal      300 non-null    object
#  13  target    302 non-null    object
# dtypes: float64(9), int64(1), object(4)
# memory usage: 33.2+ KB

# %%
#Usando o comando describe(), onde vai retornar alguns dados importantes da tabela como a média, padrão, valor min, valor maximo... vizualizando e analisando alguns dados estatístico

heart_disease_df_cleveland.describe()
# Out:
#               age          cp    trestbps  ...       exang     oldpeak       slope
# count  302.000000  302.000000  302.000000  ...  302.000000  302.000000  302.000000
# mean    54.410596    3.165563  131.645695  ...    0.327815    1.035430    1.596026
# std      9.040163    0.953612   17.612202  ...    0.470196    1.160723    0.611939
# min     29.000000    1.000000   94.000000  ...    0.000000    0.000000    1.000000
# 25%     48.000000    3.000000  120.000000  ...    0.000000    0.000000    1.000000
# 50%     55.500000    3.000000  130.000000  ...    0.000000    0.800000    2.000000
# 75%     61.000000    4.000000  140.000000  ...    1.000000    1.600000    2.000000
# max     77.000000    4.000000  200.000000  ...    1.000000    6.200000    3.000000
#
# [8 rows x 10 columns]

# %%
#Utlizando o comando count() para demonstrar a idade e quantos pacientes possui a mesma idade.

heart_disease_df_cleveland.groupby('age') ['age'].count()
# Out:
# age
# 29     1
# 34     2
# 35     4
# 37     2
# 38     2
# 39     4
# 40     3
# 41    10
# 42     8
# 43     8
# 44    11
# 45     8
# 46     7
# 47     5
# 48     7
# 49     5
# 50     7
# 51    12
# 52    13
# 53     8
# 54    16
# 55     8
# 56    11
# 57    17
# 58    19
# 59    14
# 60    12
# 61     8
# 62    11
# 63     8
# 64    10
# 65     8
# 66     7
# 67     9
# 68     4
# 69     3
# 70     4
# 71     3
# 74     1
# 76     1
# 77     1
# Name: age, dtype: int64

# %%
#Função isnull().sum() para que retorne a quantidade de valores faltantes na tabela.

heart_disease_df_cleveland.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# target      0
# dtype: int64

# %%
#Função para nos mostrar o percentual dos dados faltantes
(heart_disease_df_cleveland.isnull().sum() / len(heart_disease_df_cleveland['age']))*100
# Out:
# age         0.000000
# sex         0.000000
# cp          0.000000
# trestbps    0.000000
# chol        0.000000
# fbs         0.000000
# restecg     0.000000
# thalach     0.000000
# exang       0.000000
# oldpeak     0.000000
# slope       0.000000
# ca          1.324503
# thal        0.662252
# target      0.000000
# dtype: float64

# %%
#Usando a função round() para arredondar os valores das casas decimais do dataset

heart_disease_df_cleveland.mean().round()
# Out:
# age          54.0
# cp            3.0
# trestbps    132.0
# chol        247.0
# fbs           0.0
# restecg       1.0
# thalach     150.0
# exang         0.0
# oldpeak       1.0
# slope         2.0
# dtype: float64

# %%
#Utilização do comando count para demonstrar a quantidade de pessoas de cada sexo.

heart_disease_df_cleveland.groupby('sex')['sex'].count()
# Out:
# sex
# female     97
# male      205
# Name: sex, dtype: int64

# %%
#Função para realizar o cálculo de porcentagem
def porcentagem(x,total):
  return x * 100/total

# %%
#Contando a porcentagem de sex0

porcentagem(97,heart_disease_df_cleveland['sex'].count())
# Out:
# 32.11920529801324

# %%
#Contando a porcentagem de sex1

porcentagem(205,heart_disease_df_cleveland['sex'].count())
# Out:
# 67.88079470198676

# %%
#Criação de um gráfico de pizza para que possamos analisar o percentual de pessoas que possuem doenças cardíacas, dividido entre o sexo feminino e masculino.

labels='Feminino','Masculino'
size =[32.1,67.9]
color_list = ['pink','lightblue']
figl, axl = plt.subplots()
axl.pie(size,labels=labels,shadow = True,autopct='%1.1f%%', startangle = 90,colors=color_list)
axl.axis('equal')
axl.set_title('Quantidade de indivíduos com doenças cardíacas divididos por sexo',fontsize = 14)
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Grafico em barra com a média de idades do sexo feminino(0) e masculino(1)
media_sex1=heart_disease_df_cleveland['age'].loc[heart_disease_df_cleveland['sex']=='male'].mean()
media_sex0 = heart_disease_df_cleveland['age'].loc[heart_disease_df_cleveland['sex']=='female'].mean()
plt.title('Média de idades do sexo feminino e sexo masculino')
plt.bar('Feminino',media_sex0,color='pink')
plt.bar('Masculino',media_sex1,color='lightblue')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Usando a função hist(), para que assim mostre um histograma do sexo masculino levando em consideração a idade

heart_disease_df_cleveland['age'].loc[heart_disease_df_cleveland['sex']=='male'].hist()
plt.title('Histograma Sexo masculino x idade')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Usando a função hist(), para que assim mostre um histograma do sexo feminino levando em consideração a idade

heart_disease_df_cleveland['age'].loc[heart_disease_df_cleveland['sex']=='female'].hist()
plt.title('Histograma Sexo feminino x idade')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Utilização do comando count e groupby para demonstrar a quantidade de cada variável

heart_disease_df_cleveland.groupby('exang')['exang'].count()
# Out:
# exang
# 0.0    203
# 1.0     99
# Name: exang, dtype: int64

# %%
#Contando a porcentagem de exang "angina negativa"
porcentagem(203,heart_disease_df_cleveland['exang'].count())
# Out:
# 67.21854304635761

# %%
#Contando a porcentagem de exang "angina positiva"
porcentagem(99,heart_disease_df_cleveland['exang'].count())
# Out:
# 32.78145695364238

# %%
# Graficos em pizza de individuos com angina positiva e negativa
labels='Angina negativa','Angina positiva'
size =[67.21,32.78]
color_list = ['green','red']
figl, axl = plt.subplots()
axl.pie(size,labels=labels,shadow = True,autopct='%1.1f%%', startangle = 90,colors=color_list)
axl.axis('equal')
axl.set_title('Indivíduos com angina positiva e negativa',fontsize = 14)
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Grafico em linhas demonstrando os batimentos cadiarcos de acordo com cada sexo

plt.plot(heart_disease_df_cleveland['trestbps'].loc[heart_disease_df_cleveland['sex']=='female'],label = 'Batimentos de pessoas do sexo feminino')
plt.plot(heart_disease_df_cleveland['trestbps'].loc[heart_disease_df_cleveland['sex']=='male'],label = 'Batimentos de pessoas do sexo masculino')
plt.legend()
plt.title(' Batimentos cadiarcos de acordo com cada sexo')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Utilização do comando count para demonstrar a quantidade de cada variável

heart_disease_df_cleveland.groupby('cp')['cp'].count()
# Out:
# cp
# 1.0     22
# 2.0     50
# 3.0     86
# 4.0    144
# Name: cp, dtype: int64

# %%
# Graficos em de coluna horizontal com os tipos de dores no peito mais relatados
dores = ['angina típica','angina atípica','dor não anginosa','assitomático']
dores_num = [22,50,86,144]
plt.barh(dores,dores_num,color='blue')
plt.title('Tipos de dores no peito mais relatados')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Graficos em de coluna horizontal com a inclinação do segmento ST de pico do exercício
slope = ['inclinação ascendente','plano','declive']
slope_num= [142,140,20]
plt.barh(slope,slope_num,color='green')
plt.title('Inclinação do segmento ST de pico do exercício')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Utilização do comando count para demonstrar a quantidade de cada variável

heart_disease_df_cleveland.groupby('thal')['thal'].count()
# Out:
# thal
# 3.0    166
# 6.0     17
# 7.0    117
# Name: thal, dtype: int64

# %%
# Graficos coluna com média da frequência cardiaca (normal, defeito corrigido, defeito reversível) 
thal = ['normal','defeito corrigido','defeito reversível']
thal_num = [166,17,117]
plt.bar(thal,thal_num,color = 'darkred')
plt.title('Frequência cardiaca (normal, defeito corrigido, defeito reversível)')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
# Histograficos sobre depressão de ST induzida por exercício em relação ao repouso pelo sexo biologico masculino
heart_disease_df_cleveland['oldpeak'].loc[heart_disease_df_cleveland['sex']=='male'].hist()
plt.title('Depressão de ST induzida por exercício em relação ao repouso pelo sexo biologico masculino')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
# Histograficos sobre depressão de ST induzida por exercício em relação ao repouso pelo sexo biologico feminino
heart_disease_df_cleveland['oldpeak'].loc[heart_disease_df_cleveland['sex']=='female'].hist()
plt.title('Depressão de ST induzida por exercício em relação ao repouso pelo sexo biologico feminino')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Utilização do comando count para demonstrar a quantidade de cada variável
heart_disease_df_cleveland.groupby('ca')['ca'].count()
# Out:
# ca
# 0.0    175
# 1.0     65
# 2.0     38
# 3.0     20
# Name: ca, dtype: int64

# %%
#Graficos em colunas contendo número de vasos principais (0-3) coloridos por fluorosopia
ca = ['0.0','1.0','2.0','3.0']
ca_num = [175,65,38,20]
plt.bar(ca,ca_num,color = 'yellow')
plt.title('Número de vasos principais (0-3) coloridos por fluorosopia')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Utilização do comando count para demonstrar a quantidade de cada variável
heart_disease_df_cleveland.groupby('fbs')['fbs'].count()
# Out:
# fbs
# 0.0    258
# 1.0     44
# Name: fbs, dtype: int64

# %%
#Contando a porcentagem de açucar no sangue positivo
porcentagem(258,heart_disease_df_cleveland['fbs'].count())
# Out:
# 85.43046357615894

# %%
#Contando a porcentagem de açucar no sangue negativo
porcentagem(44,heart_disease_df_cleveland['fbs'].count())
# Out:
# 14.56953642384106

# %%
#Criação de um gráfico de pizza contendo o percentual de açúcar no sangue
labels='Açúcar no sangue positivo','Açúcar no sangue negativo'
size =[85.43,14.56]
color_list = ['blue','orange']
figl, axl = plt.subplots()
axl.pie(size,labels=labels,shadow = True,autopct='%1.1f%%', startangle = 90,colors=color_list)
axl.axis('equal')
axl.set_title('Indivíduos com açucar no sangue positivo e negativo',fontsize = 14)
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Utilização do comando count para demonstrar a quantidade de cada variável
heart_disease_df_cleveland.groupby('target')['target'].count()
# Out:
# target
# no     163
# yes    139
# Name: target, dtype: int64

# %%
# Histograma sobre indivíduos do sexo feminino que possuem ou não doenças do coração
heart_disease_df_cleveland['target'].loc[heart_disease_df_cleveland['sex']=='female'].hist()
plt.title('Indivíduos do sexo feminino que possuem ou não doenças do coração')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
# Hist() sobre indivíduos do sexo masculino que possuem ou não doenças do coração
heart_disease_df_cleveland['target'].loc[heart_disease_df_cleveland['sex']=='male'].hist()
plt.title('Indivíduos do sexo masculino que possuem ou não doenças do coração')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
# Histograma sobre indivíduos que possuem doenças do coração em relação a idade
heart_disease_df_cleveland['age'].loc[heart_disease_df_cleveland['target']=='yes'].hist()
plt.title('Indivíduos que possuem a doenças do coração em relação')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
# Histograma sobre indivíduos que não possuem doenças do coração em relação a idade
heart_disease_df_cleveland['age'].loc[heart_disease_df_cleveland['target']=='no'].hist()
plt.title('Indivíduos que não possuem a doenças do coração em relação')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Utilizando a função sns.heatmap para que plote os dados e gere uma matriz de correlação 

plt.figure(figsize=(10,10))
sns.heatmap(heart_disease_df_cleveland.corr(),annot= True,cmap='YlGn' ,vmin = -1, vmax = 1)
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %% [markdown]
# # **Análise exploratória dos dados da Suíça**

# %%
#Utlizindo a função head() para que assim retorne as 5 primeiras linhas do dataset e mostre os seus dados.

heart_disease_df_switzerland.head()
# Out:
#    age  sex  cp trestbps  chol fbs  ... exang oldpeak slope ca thal target
# 0   34    1   4      115     0   ?  ...     0      .2     1  ?    ?      1
# 1   35    1   4        ?     0   ?  ...     1       ?     ?  ?    7      3
# 2   36    1   4      110     0   ?  ...     1       1     2  ?    6      1
# 3   38    0   4      105     0   ?  ...     0     2.8     1  ?    ?      2
# 4   38    0   4      110     0   0  ...     0       0     2  ?    3      1
#
# [5 rows x 14 columns]

# %%
#Normalização das tabelas

heart_disease_df_switzerland['age'] = heart_disease_df_switzerland['age'].apply(lambda x: None if x == '?' else x) 
heart_disease_df_switzerland['sex'] = heart_disease_df_switzerland['sex'].apply(lambda x: None if x == '?' else x)
heart_disease_df_switzerland['cp'] = heart_disease_df_switzerland['cp'].apply(lambda x: None if x == '?' else x)
heart_disease_df_switzerland['trestbps'] = heart_disease_df_switzerland['trestbps'].apply(lambda x: None if x == '?' else x)
heart_disease_df_switzerland['fbs'] = heart_disease_df_switzerland['fbs'].apply(lambda x: None if x == '?' else x)
heart_disease_df_switzerland['restecg'] = heart_disease_df_switzerland['restecg'].apply(lambda x: None if x == '?' else x) 
heart_disease_df_switzerland['thalach'] = heart_disease_df_switzerland['thalach'].apply(lambda x: None if x == '?' else x)
heart_disease_df_switzerland['exang'] = heart_disease_df_switzerland['exang'].apply(lambda x: None if x == '?' else x)
heart_disease_df_switzerland['oldpeak'] = heart_disease_df_switzerland['oldpeak'].apply(lambda x: None if x == '?' else x)
heart_disease_df_switzerland['slope'] = heart_disease_df_switzerland['slope'].apply(lambda x: None if x == '?' else x)
heart_disease_df_switzerland['ca'] = heart_disease_df_switzerland['ca'].apply(lambda x: None if x == '?' else x)
heart_disease_df_switzerland['thal'] = heart_disease_df_switzerland['thal'].apply(lambda x: None if x == '?' else x)
heart_disease_df_switzerland['target'] = heart_disease_df_switzerland['target'].apply(lambda x: None if x == '?' else x)

heart_disease_df_switzerland.head()
# Out:
#    age  sex  cp trestbps  chol   fbs  ... exang oldpeak slope    ca  thal target
# 0   34    1   4      115     0  None  ...     0      .2     1  None  None      1
# 1   35    1   4     None     0  None  ...     1    None  None  None     7      3
# 2   36    1   4      110     0  None  ...     1       1     2  None     6      1
# 3   38    0   4      105     0  None  ...     0     2.8     1  None  None      2
# 4   38    0   4      110     0     0  ...     0       0     2  None     3      1
#
# [5 rows x 14 columns]

# %%
#Utilização do comando "astype" para pegar o determinado valor e converter ele para float

heart_disease_df_switzerland['cp']= heart_disease_df_switzerland['cp'].astype(float)
heart_disease_df_switzerland['trestbps']= heart_disease_df_switzerland['trestbps'].astype(float)
heart_disease_df_switzerland['chol']= heart_disease_df_switzerland['chol'].astype(float)
heart_disease_df_switzerland['fbs']= heart_disease_df_switzerland['fbs'].astype(float)
heart_disease_df_switzerland['restecg']= heart_disease_df_switzerland['restecg'].astype(float)
heart_disease_df_switzerland['thalach']= heart_disease_df_switzerland['thalach'].astype(float)
heart_disease_df_switzerland['exang']= heart_disease_df_switzerland['exang'].astype(float)
heart_disease_df_switzerland['oldpeak']= heart_disease_df_switzerland['oldpeak'].astype(float)
heart_disease_df_switzerland['slope']= heart_disease_df_switzerland['slope'].astype(float)
heart_disease_df_switzerland['oldpeak']= heart_disease_df_switzerland['oldpeak'].astype(float)
heart_disease_df_switzerland['ca']= heart_disease_df_switzerland['ca'].astype(float)
heart_disease_df_switzerland['thal']= heart_disease_df_switzerland['thal'].astype(float)

heart_disease_df_switzerland.head()
# Out:
#    age  sex   cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   34    1  4.0     115.0   0.0  NaN  ...    0.0      0.2    1.0 NaN   NaN       1
# 1   35    1  4.0       NaN   0.0  NaN  ...    1.0      NaN    NaN NaN   7.0       3
# 2   36    1  4.0     110.0   0.0  NaN  ...    1.0      1.0    2.0 NaN   6.0       1
# 3   38    0  4.0     105.0   0.0  NaN  ...    0.0      2.8    1.0 NaN   NaN       2
# 4   38    0  4.0     110.0   0.0  0.0  ...    0.0      0.0    2.0 NaN   3.0       1
#
# [5 rows x 14 columns]

# %%
#Utilização do comando "astype" para pegar o determinado valor e converter ele para object

heart_disease_df_switzerland['ca']= heart_disease_df_switzerland['ca'].astype(object)
heart_disease_df_switzerland['thal']= heart_disease_df_switzerland['thal'].astype(object)

# %%
heart_disease_df_switzerland['target'] =  heart_disease_df_switzerland.target.replace([1,2,3,4],['yes','yes','yes','yes'])
heart_disease_df_switzerland['target'] =  heart_disease_df_switzerland.target.replace([0],['no'])

# %%
heart_disease_df_switzerland['sex'] =  heart_disease_df_switzerland.sex.replace([0,1],['female','male'])

# %%
#Utilizando a função info(), para que assim demonstre uma visão geral do nosso dataset

heart_disease_df_switzerland.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       122 non-null    int64
#  1   sex       122 non-null    object
#  2   cp        122 non-null    float64
#  3   trestbps  120 non-null    float64
#  4   chol      122 non-null    float64
#  5   fbs       48 non-null     float64
#  6   restecg   121 non-null    float64
#  7   thalach   121 non-null    float64
#  8   exang     121 non-null    float64
#  9   oldpeak   116 non-null    float64
#  10  slope     105 non-null    float64
#  11  ca        5 non-null      object
#  12  thal      71 non-null     object
#  13  target    122 non-null    object
# dtypes: float64(9), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
#Usando o comando describe(), onde vai retornar alguns dados importantes da tabela como a média, padrão, valor min, valor maximo... vizualizando e analisando alguns dados estatístico


heart_disease_df_switzerland.describe()
# Out:
#               age          cp    trestbps  ...       exang     oldpeak       slope
# count  122.000000  122.000000  120.000000  ...  121.000000  116.000000  105.000000
# mean    55.508197    3.721311  130.500000  ...    0.446281    0.653448    1.809524
# std      8.816069    0.646188   22.420729  ...    0.499173    1.060634    0.621649
# min     34.000000    1.000000   80.000000  ...    0.000000   -2.600000    1.000000
# 25%     51.000000    4.000000  115.000000  ...    0.000000    0.000000    1.000000
# 50%     56.000000    4.000000  127.500000  ...    0.000000    0.300000    2.000000
# 75%     61.750000    4.000000  145.000000  ...    1.000000    1.500000    2.000000
# max     74.000000    4.000000  200.000000  ...    1.000000    3.700000    3.000000
#
# [8 rows x 10 columns]

# %%
#Função isnull().sum() para que retorne a quantidade de valores faltantes na tabela.

heart_disease_df_switzerland.isnull().sum()
# Out:
# age           0
# sex           0
# cp            0
# trestbps      2
# chol          0
# fbs          74
# restecg       1
# thalach       1
# exang         1
# oldpeak       6
# slope        17
# ca          117
# thal         51
# target        0
# dtype: int64

# %%
#Função para nos mostrar o percentual dos dados faltantes

(heart_disease_df_switzerland.isnull().sum() / len(heart_disease_df_switzerland['age']))*100
# Out:
# age          0.000000
# sex          0.000000
# cp           0.000000
# trestbps     1.639344
# chol         0.000000
# fbs         60.655738
# restecg      0.819672
# thalach      0.819672
# exang        0.819672
# oldpeak      4.918033
# slope       13.934426
# ca          95.901639
# thal        41.803279
# target       0.000000
# dtype: float64

# %%
#Utilizando a função isnull().head(), para que nos mostre onde tem os dados faltantes, onde False significa que possui dados e True quer dizer que tem dados faltantes.

heart_disease_df_switzerland.isnull().head()
# Out:
#      age    sex     cp  trestbps   chol  ...  oldpeak  slope    ca   thal  target
# 0  False  False  False     False  False  ...    False  False  True   True   False
# 1  False  False  False      True  False  ...     True   True  True  False   False
# 2  False  False  False     False  False  ...    False  False  True  False   False
# 3  False  False  False     False  False  ...    False  False  True   True   False
# 4  False  False  False     False  False  ...    False  False  True  False   False
#
# [5 rows x 14 columns]

# %%
#Retirar colunas do dataset
del heart_disease_df_switzerland['chol']
del heart_disease_df_switzerland['ca']

# %%
#Usando a função round() para arredondar os valores das casas decimais do dataset

heart_disease_df_switzerland.round()
# Out:
#      age     sex   cp  trestbps  fbs  ...  exang  oldpeak  slope  thal  target
# 0     34    male  4.0     115.0  NaN  ...    0.0      0.0    1.0   NaN     yes
# 1     35    male  4.0       NaN  NaN  ...    1.0      NaN    NaN     7     yes
# 2     36    male  4.0     110.0  NaN  ...    1.0      1.0    2.0     6     yes
# 3     38  female  4.0     105.0  NaN  ...    0.0      3.0    1.0   NaN     yes
# 4     38  female  4.0     110.0  0.0  ...    0.0      0.0    2.0     3     yes
# ..   ...     ...  ...       ...  ...  ...    ...      ...    ...   ...     ...
# 117   70    male  4.0     115.0  0.0  ...    1.0      0.0    2.0     7     yes
# 118   70    male  4.0     140.0  1.0  ...    1.0      2.0    2.0     7     yes
# 119   72    male  3.0     160.0  NaN  ...    0.0      2.0    2.0   NaN      no
# 120   73  female  3.0     160.0  0.0  ...    0.0      0.0    1.0     3     yes
# 121   74    male  2.0     145.0  NaN  ...    0.0      1.0    1.0   NaN     yes
#
# [122 rows x 12 columns]

# %%
#Utilização do comando count para demonstrar a quantidade de cada variável

heart_disease_df_switzerland.groupby('sex')['sex'].count()
# Out:
# sex
# female     10
# male      112
# Name: sex, dtype: int64

# %%
#Criação de um gráfico de pizza para que possamos analisar o percentual de pessoas que possuem doenças cardíacas, dividido entre o sexo feminino e masculino. 

labels='Feminino','Masculino'
size =[8.2,91.8]
color_list = ['pink','lightblue']
figl, axl = plt.subplots()
axl.pie(size,labels=labels,shadow = True,autopct='%1.1f%%', startangle = 90,colors=color_list)
axl.axis('equal')
axl.set_title('Quantidade de indivíduos com doenças cardíacas divididos por sexo',fontsize = 14)
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Grafico em barra com a média de idades do sexo feminino(0) e masculino(1)
media_sex1=heart_disease_df_switzerland['age'].loc[heart_disease_df_switzerland['sex']=='male'].mean()
media_sex0 = heart_disease_df_switzerland['age'].loc[heart_disease_df_switzerland['sex']=='female'].mean()
plt.title('Média de idades do sexo feminino e sexo masculino')
plt.bar('Feminino',media_sex0,color='pink')
plt.bar('Masculino',media_sex1,color='lightblue')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Usando a função hist(), para que assim mostre um histograma do sexo feminino levando em consideração a idade
heart_disease_df_switzerland['age'].loc[heart_disease_df_switzerland['sex']=='female'].hist()
plt.title('Histograma Sexo feminino x idade')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Usando a função hist(), para que assim mostre um histograma do sexo masculino levando em consideração a idade
heart_disease_df_switzerland['age'].loc[heart_disease_df_switzerland['sex']=='male'].hist()
plt.title('Histograma Sexo masculino x idade')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Usando a função hist(), para que assim mostre um histograma da idade e quem ficou debilitado

heart_disease_df_switzerland['age'].loc[heart_disease_df_switzerland['exang']==0].hist()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Grafico em linhas demonstrando os batimentos cadiarcos de acordo com cada sexo

plt.plot(heart_disease_df_switzerland['trestbps'].loc[heart_disease_df_switzerland['sex']=='female'],label = 'Batimentos de pessoas do sexo 0(F)')
plt.plot(heart_disease_df_switzerland['trestbps'].loc[heart_disease_df_switzerland['sex']=='male'],label = 'Batimentos de pessoas do sexo 1(M)')
plt.legend()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Utilização do comando count e groupby para demonstrar a quantidade de cada variável

heart_disease_df_switzerland.groupby('slope')['slope'].count()
# Out:
# slope
# 1.0    32
# 2.0    61
# 3.0    12
# Name: slope, dtype: int64

# %%
#Graficos em de coluna horizontal com a inclinação do segmento ST de pico do exercício
slope = ['inclinação ascendente','plano','declive']
slope_num= [32,61,12]
plt.barh(slope,slope_num,color='green')
plt.title('Inclinação do segmento ST de pico do exercício')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Utilização do comando count e groupby para demonstrar a quantidade de cada variável
heart_disease_df_switzerland.groupby('exang')['exang'].count()
# Out:
# exang
# 0.0    67
# 1.0    54
# Name: exang, dtype: int64

# %%
#Cáculo da porcentagem de cada variável da coluna exang
#porcentagem(67,heart_disease_df_switzerland['exang'].count())
porcentagem(54,heart_disease_df_switzerland['exang'].count())
# Out:
# 44.62809917355372

# %%
# Graficos em pizza de individuos com angina positiva e negativa
labels='Angina negativa','Angina positiva'
size =[55.37,44.62]
color_list = ['green','red']
figl, axl = plt.subplots()
axl.pie(size,labels=labels,shadow = True,autopct='%1.1f%%', startangle = 90,colors=color_list)
axl.axis('equal')
axl.set_title('Indivíduos com angina positiva e negativa',fontsize = 14)
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Utilização do comando count e groupby para demonstrar a quantidade de cada variável

heart_disease_df_switzerland.groupby('cp')['cp'].count()
# Out:
# cp
# 1.0     3
# 2.0     4
# 3.0    17
# 4.0    98
# Name: cp, dtype: int64

# %%
# Graficos em de coluna horizontal com os tipos de dores no peito mais relatados
dores = ['angina típica','angina atípica','dor não anginosa','assitomático']
dores_num = [3,4,17,98]
plt.barh(dores,dores_num,color='pink')
plt.title('Tipos de dores no peito mais relatados')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Utilização do comando count para demonstrar a quantidade de cada variável

heart_disease_df_switzerland.groupby('thal')['thal'].count()
# Out:
# thal
# 3.0    19
# 6.0    10
# 7.0    42
# Name: thal, dtype: int64

# %%
#Criação de um gráfico de pizza para que possamos analisar cardiaca (normal, defeito corrigido, defeito reversível) 

labels= 'normal','defeito corrigido','defeito reversível'
size =[26.7,14.08,59.22]
color_list = ['blue','yellow','red']
figl, axl = plt.subplots()
axl.pie(size,labels=labels,shadow = True,autopct='%1.1f%%', startangle = 90,colors=color_list)
axl.axis('equal')
axl.set_title('Quantidade de indivíduos com doenças cardíacas divididos por sexo',fontsize = 14)
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Utilização do comando count para demonstrar a quantidade de cada variável
heart_disease_df_switzerland.groupby('fbs')['fbs'].count()
# Out:
# fbs
# 0.0    43
# 1.0     5
# Name: fbs, dtype: int64

# %%
#Cáculo da porcentagem de cada variável da coluna fbs
porcentagem(43,heart_disease_df_switzerland['fbs'].count())
# Out:
# 89.58333333333333

# %%
porcentagem(5,heart_disease_df_switzerland['fbs'].count())
# Out:
# 10.416666666666666

# %%
#Criação de um gráfico de pizza contendo o percentual de açúcar no sangue
labels='Açúcar no sangue positivo','Açúcar no sangue negativo'
size =[89.58,10.41]
color_list = ['blue','orange']
figl, axl = plt.subplots()
axl.pie(size,labels=labels,shadow = True,autopct='%1.1f%%', startangle = 90,colors=color_list)
axl.axis('equal')
axl.set_title('Indivíduos com açucar no sangue positivo e negativo',fontsize = 14)
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Utilização do comando count para demonstrar a quantidade de cada variável
heart_disease_df_switzerland.groupby('thal')['thal'].count()
# Out:
# thal
# 3.0    19
# 6.0    10
# 7.0    42
# Name: thal, dtype: int64

# %%
# Graficos coluna com média da frequência cardiaca (normal, defeito corrigido, defeito reversível)
thal = ['normal','defeito corrigido','defeito reversível']
thal_num = [19,10,42]
plt.bar(thal,thal_num,color = 'darkred')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
# Histograficos sobre depressão de ST induzida por exercício em relação ao repouso pelo sexo biologico masculino
heart_disease_df_switzerland['oldpeak'].loc[heart_disease_df_switzerland['sex']=='male'].hist()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
# Histograficos sobre depressão de ST induzida por exercício em relação ao repouso pelo sexo biologico feminino
heart_disease_df_switzerland['oldpeak'].loc[heart_disease_df_switzerland['sex']=='female'].hist()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
# Histograma sobre indivíduos que não possuem doenças do coração em relação a idade
heart_disease_df_switzerland['age'].loc[heart_disease_df_switzerland['target']=='no'].hist()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
# Histograma sobre indivíduos que possuem doenças do coração em relação a idade
heart_disease_df_switzerland['age'].loc[heart_disease_df_switzerland['target']=='yes'].hist()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
# Histograma sobre indivíduos do sexo feminino que possuem ou não doenças do coração
heart_disease_df_switzerland['target'].loc[heart_disease_df_switzerland['sex']=='female'].hist()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
# Histograma sobre indivíduos do sexo masculino que possuem ou não doenças do coração
heart_disease_df_switzerland['target'].loc[heart_disease_df_switzerland['sex']=='male'].hist()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Utilizando a função sns.heatmap para que plote os dados e gere uma matriz de correlação 

plt.figure(figsize=(10,10))
sns.heatmap(heart_disease_df_switzerland.corr(),annot= True,cmap='YlGn' ,vmin = -1, vmax = 1)
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %% [markdown]
# # **Análise exploratória dos dados da Hungria**

# %%
#Utlizindo a função head() para que assim retorne as 5 primeiras linhas do dataset e mostre os seus dados.

heart_disease_df_hungarian.head()
# Out:
#    age  sex  cp trestbps chol fbs  ... exang oldpeak slope  ca thal target
# 0   29    1   2      120  243   0  ...     0     0.0     ?   ?    ?      0
# 1   29    1   2      140    ?   0  ...     0     0.0     ?   ?    ?      0
# 2   30    0   1      170  237   0  ...     0     0.0     ?   ?    6      0
# 3   31    0   2      100  219   0  ...     0     0.0     ?   ?    ?      0
# 4   32    0   2      105  198   0  ...     0     0.0     ?   ?    ?      0
#
# [5 rows x 14 columns]

# %%
#Normalização das tabelas.

heart_disease_df_hungarian['age'] = heart_disease_df_hungarian['age'].apply(lambda x: None if x == '?' else x) 
heart_disease_df_hungarian['sex'] = heart_disease_df_hungarian['sex'].apply(lambda x: None if x == '?' else x)
heart_disease_df_hungarian['cp'] = heart_disease_df_hungarian['cp'].apply(lambda x: None if x == '?' else x)
heart_disease_df_hungarian['trestbps'] = heart_disease_df_hungarian['trestbps'].apply(lambda x: None if x == '?' else x)
heart_disease_df_hungarian['chol'] = heart_disease_df_hungarian['chol'].apply(lambda x: None if x == '?' else x)
heart_disease_df_hungarian['fbs'] = heart_disease_df_hungarian['fbs'].apply(lambda x: None if x == '?' else x)
heart_disease_df_hungarian['restecg'] = heart_disease_df_hungarian['restecg'].apply(lambda x: None if x == '?' else x) 
heart_disease_df_hungarian['thalach'] = heart_disease_df_hungarian['thalach'].apply(lambda x: None if x == '?' else x)
heart_disease_df_hungarian['exang'] = heart_disease_df_hungarian['exang'].apply(lambda x: None if x == '?' else x)
heart_disease_df_hungarian['oldpeak'] = heart_disease_df_hungarian['oldpeak'].apply(lambda x: None if x == '?' else x)
heart_disease_df_hungarian['slope'] = heart_disease_df_hungarian['slope'].apply(lambda x: None if x == '?' else x)
heart_disease_df_hungarian['ca'] = heart_disease_df_hungarian['ca'].apply(lambda x: None if x == '?' else x)
heart_disease_df_hungarian['thal'] = heart_disease_df_hungarian['thal'].apply(lambda x: None if x == '?' else x)
heart_disease_df_hungarian['target'] = heart_disease_df_hungarian['target'].apply(lambda x: None if x == '?' else x)
heart_disease_df_hungarian.head()
# Out:
#    age  sex  cp trestbps  chol fbs  ... exang oldpeak slope    ca  thal target
# 0   29    1   2      120   243   0  ...     0     0.0  None  None  None      0
# 1   29    1   2      140  None   0  ...     0     0.0  None  None  None      0
# 2   30    0   1      170   237   0  ...     0     0.0  None  None     6      0
# 3   31    0   2      100   219   0  ...     0     0.0  None  None  None      0
# 4   32    0   2      105   198   0  ...     0     0.0  None  None  None      0
#
# [5 rows x 14 columns]

# %%
#Utilização do comando "astype" para pegar o determinado valor e converter ele para float

heart_disease_df_hungarian['cp']= heart_disease_df_hungarian['cp'].astype(float)
heart_disease_df_hungarian['trestbps']= heart_disease_df_hungarian['trestbps'].astype(float)
heart_disease_df_hungarian['chol']= heart_disease_df_hungarian['chol'].astype(float)
heart_disease_df_hungarian['fbs']= heart_disease_df_hungarian['fbs'].astype(float)
heart_disease_df_hungarian['restecg']= heart_disease_df_hungarian['restecg'].astype(float)
heart_disease_df_hungarian['thalach']= heart_disease_df_hungarian['thalach'].astype(float)
heart_disease_df_hungarian['exang']= heart_disease_df_hungarian['exang'].astype(float)
heart_disease_df_hungarian['oldpeak']= heart_disease_df_hungarian['oldpeak'].astype(float)
heart_disease_df_hungarian['slope']= heart_disease_df_hungarian['slope'].astype(float)
heart_disease_df_hungarian['oldpeak']= heart_disease_df_hungarian['oldpeak'].astype(float)
heart_disease_df_hungarian['ca']= heart_disease_df_hungarian['ca'].astype(float)
heart_disease_df_hungarian['thal']=heart_disease_df_hungarian['thal'].astype(float)

# %%
#Utilização do comando "astype" para pegar o determinado valor e converter ele para object

heart_disease_df_hungarian['ca']= heart_disease_df_hungarian['ca'].astype(object)
heart_disease_df_hungarian['thal']= heart_disease_df_hungarian['thal'].astype(object)

# %%
heart_disease_df_hungarian['target'] =  heart_disease_df_hungarian.target.replace([1,2,3,4],['yes','yes','yes','yes'])
heart_disease_df_hungarian['target'] =  heart_disease_df_hungarian.target.replace([0],['no'])

# %%
heart_disease_df_hungarian['sex'] =  heart_disease_df_hungarian.sex.replace([0,1],['female','male'])

# %%
#Retornando os dados com os alguns valores deles convertidos

heart_disease_df_hungarian.head()
# Out:
#    age     sex   cp  trestbps   chol  ...  oldpeak  slope   ca  thal  target
# 0   29    male  2.0     120.0  243.0  ...      0.0    NaN  NaN   NaN      no
# 1   29    male  2.0     140.0    NaN  ...      0.0    NaN  NaN   NaN      no
# 2   30  female  1.0     170.0  237.0  ...      0.0    NaN  NaN     6      no
# 3   31  female  2.0     100.0  219.0  ...      0.0    NaN  NaN   NaN      no
# 4   32  female  2.0     105.0  198.0  ...      0.0    NaN  NaN   NaN      no
#
# [5 rows x 14 columns]

# %%
#Utilizando a função info(), para que assim demonstre uma visão geral do nosso dataset

heart_disease_df_hungarian.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       293 non-null    int64
#  1   sex       293 non-null    object
#  2   cp        293 non-null    float64
#  3   trestbps  292 non-null    float64
#  4   chol      270 non-null    float64
#  5   fbs       285 non-null    float64
#  6   restecg   292 non-null    float64
#  7   thalach   292 non-null    float64
#  8   exang     292 non-null    float64
#  9   oldpeak   293 non-null    float64
#  10  slope     104 non-null    float64
#  11  ca        3 non-null      object
#  12  thal      28 non-null     object
#  13  target    293 non-null    object
# dtypes: float64(9), int64(1), object(4)
# memory usage: 32.2+ KB

# %%
#Usando o comando describe(), onde vai retornar alguns dados importantes da tabela como a média, padrão, valor min, valor maximo... vizualizando e analisando alguns dados estatístico

heart_disease_df_hungarian.describe()
# Out:
#               age          cp    trestbps  ...       exang     oldpeak       slope
# count  293.000000  293.000000  292.000000  ...  292.000000  293.000000  104.000000
# mean    47.894198    2.986348  132.592466  ...    0.304795    0.588055    1.894231
# std      7.738385    0.965049   17.656176  ...    0.461111    0.909554    0.338995
# min     29.000000    1.000000   92.000000  ...    0.000000    0.000000    1.000000
# 25%     42.000000    2.000000  120.000000  ...    0.000000    0.000000    2.000000
# 50%     49.000000    3.000000  130.000000  ...    0.000000    0.000000    2.000000
# 75%     54.000000    4.000000  140.000000  ...    1.000000    1.000000    2.000000
# max     66.000000    4.000000  200.000000  ...    1.000000    5.000000    3.000000
#
# [8 rows x 10 columns]

# %%
#Função isnull().sum() para que retorne a quantidade de valores faltantes na tabela.

heart_disease_df_hungarian.isnull().sum()
# Out:
# age           0
# sex           0
# cp            0
# trestbps      1
# chol         23
# fbs           8
# restecg       1
# thalach       1
# exang         1
# oldpeak       0
# slope       189
# ca          290
# thal        265
# target        0
# dtype: int64

# %%
#Cálculo da porcentagem de dados nulos do dataset
(heart_disease_df_hungarian.isnull().sum() / len(heart_disease_df_hungarian['age']))*100
# Out:
# age          0.000000
# sex          0.000000
# cp           0.000000
# trestbps     0.341297
# chol         7.849829
# fbs          2.730375
# restecg      0.341297
# thalach      0.341297
# exang        0.341297
# oldpeak      0.000000
# slope       64.505119
# ca          98.976109
# thal        90.443686
# target       0.000000
# dtype: float64

# %%
#Retirar as colunas do dataset
del heart_disease_df_hungarian['thal']
del heart_disease_df_hungarian['slope']
del heart_disease_df_hungarian['ca']

# %%
#Usando a função round() para arredondar os valores das casas decimais do dataset

heart_disease_df_hungarian.round()
# Out:
#      age     sex   cp  trestbps   chol  ...  restecg  thalach  exang  oldpeak  target
# 0     29    male  2.0     120.0  243.0  ...      0.0    160.0    0.0      0.0      no
# 1     29    male  2.0     140.0    NaN  ...      0.0    170.0    0.0      0.0      no
# 2     30  female  1.0     170.0  237.0  ...      1.0    170.0    0.0      0.0      no
# 3     31  female  2.0     100.0  219.0  ...      1.0    150.0    0.0      0.0      no
# 4     32  female  2.0     105.0  198.0  ...      0.0    165.0    0.0      0.0      no
# ..   ...     ...  ...       ...    ...  ...      ...      ...    ...      ...     ...
# 288   52    male  4.0     160.0  331.0  ...      0.0     94.0    1.0      2.0     yes
# 289   54  female  3.0     130.0  294.0  ...      1.0    100.0    1.0      0.0     yes
# 290   56    male  4.0     155.0  342.0  ...      0.0    150.0    1.0      3.0     yes
# 291   58  female  2.0     180.0  393.0  ...      0.0    110.0    1.0      1.0     yes
# ...

# %%
#Utilização do comando count para demonstrar a quantidade de cada variável

heart_disease_df_hungarian.groupby('sex')['sex'].count()
# Out:
# sex
# female     81
# male      212
# Name: sex, dtype: int64

# %%
#Criação de um gráfico de pizza para que possamos analisar 

labels='Feminino','Masculino'
size =[27.6,72.4]
color_list = ['pink','lightblue']
figl, axl = plt.subplots()
axl.pie(size,labels=labels,shadow = True,autopct='%1.1f%%', startangle = 90,colors=color_list)
axl.axis('equal')
axl.set_title('Quantidade de indivíduos com doenças cardíacas divididos por sexo',fontsize = 14)
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Grafico em barras sobre m´dia de idades do sexo feminino e masculino
media_sex1=heart_disease_df_hungarian['age'].loc[heart_disease_df_hungarian['sex']=='male'].mean()
media_sex0 = heart_disease_df_hungarian['age'].loc[heart_disease_df_hungarian['sex']=='female'].mean()
plt.title('Média de idades do sexo feminino e sexo masculino')
plt.bar('Feminino',media_sex0,color='pink')
plt.bar('Masculino',media_sex1,color='lightblue')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#hist() Relação idade e sexo masculino
heart_disease_df_hungarian['age'].loc[heart_disease_df_hungarian['sex']=='male'].hist()
plt.title('Histograma Sexo masculino x idade')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#hist() Relação idade e sexo feminino
heart_disease_df_hungarian['age'].loc[heart_disease_df_hungarian['sex']=='female'].hist()
plt.title('Histograma Sexo feminino x idade')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
# Hist() Relação de idade e individuo com angina
heart_disease_df_hungarian['age'].loc[heart_disease_df_hungarian['exang']==0].hist()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.title("Relação de idade e individuo com angina")
plt.show()

# %%
# Hist() Relação de idade e individuo com angina
heart_disease_df_hungarian['age'].loc[heart_disease_df_hungarian['exang']==1].hist()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.title("Relação de idade e individuo csem angina")
plt.show()

# %%
#Grafico em linhas demonstrando os batimentos cadiarcos de acordo com cada sexo

plt.plot(heart_disease_df_hungarian['trestbps'].loc[heart_disease_df_hungarian['sex']=='female'],label = 'Batimentos de pessoas do sexo 0(F)')
plt.plot(heart_disease_df_hungarian['trestbps'].loc[heart_disease_df_hungarian['sex']=='male'],label = 'Batimentos de pessoas do sexo 1(M)')
plt.legend()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Utilização do comando count para demonstrar a quantidade de cada variável

heart_disease_df_hungarian.groupby('cp')['cp'].count()
# Out:
# cp
# 1.0     11
# 2.0    105
# 3.0     54
# 4.0    123
# Name: cp, dtype: int64

# %%
# Graficos em de coluna horizontal com os tipos de dores no peito mais relatados
dores = ['angina típica','angina atípica','dor não anginosa','assitomático']
dores_num = [11,105,54,123]
plt.barh(dores,dores_num,color='yellow')
plt.title('Tipos de dores no peito mais relatadas')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Utilização do comando count para demonstrar a quantidade de cada variável
heart_disease_df_hungarian.groupby('exang')['exang'].count()
# Out:
# exang
# 0.0    203
# 1.0     89
# Name: exang, dtype: int64

# %%
#Utilização do graficos de pizza praa mostra a relação entre angina positiva e angina negativa
labels='Angina negativa','Angina positiva'
size =[203,89]
color_list = ['green','red']
figl, axl = plt.subplots()
axl.pie(size,labels=labels,shadow = True,autopct='%1.1f%%', startangle = 90,colors=color_list)
axl.axis('equal')
axl.set_title('Indivíduos com angina positiva e negativa',fontsize = 14)
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Utilização do comando count para demonstrar a quantidade de cada variável
heart_disease_df_hungarian.groupby('fbs')['fbs'].count()
# Out:
# fbs
# 0.0    265
# 1.0     20
# Name: fbs, dtype: int64

# %%
#Utilização do grafico de pizza para mostra a relação de áçucar positivo e áçucar negativo
labels='Açúcar no sangue positivo','Açúcar no sangue negativo'
size =[256,20]
color_list = ['blue','orange']
figl, axl = plt.subplots()
axl.pie(size,labels=labels,shadow = True,autopct='%1.1f%%', startangle = 90,colors=color_list)
axl.axis('equal')
axl.set_title('Indivíduos com açucar no sangue positivo e negativo',fontsize = 14)
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#hist() sobre relação entre idade e presença de doenças do coração
heart_disease_df_hungarian['age'].loc[heart_disease_df_hungarian['target']=='yes'].hist()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.title("Relação entre idade e presença de doenças do coração")
plt.show()

# %%
#hist() sobre relação entre idade e presença de doenças do coração
heart_disease_df_hungarian['age'].loc[heart_disease_df_hungarian['target']=='no'].hist()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.title("Relação entre idade e não presença de doenças do coração")
plt.show()

# %%
#hist() sobre relação entre sexo masculino e presença de doenças do coração
heart_disease_df_hungarian['target'].loc[heart_disease_df_hungarian['sex']=='male'].hist()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.title("Relação entre sexo masculino e presença de doenças do coração")
plt.show()

# %%
#hist() sobre relação entre sexo feminino e presença de doenças do coração
heart_disease_df_hungarian['target'].loc[heart_disease_df_hungarian['sex']=='female'].hist()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.title("Relação entre sexo masculino e presença de doenças do coração")
plt.show()

# %%
#Utilizando a função sns.heatmap para que plote os dados e gere uma matriz de correlação 

plt.figure(figsize=(10,10))
sns.heatmap(heart_disease_df_hungarian.corr(),annot= True,cmap='YlGn' ,vmin = -1, vmax = 1)
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %% [markdown]
# # **Análise exploratória dos dados da Califónia**

# %%
#Utlizindo a função head() para que assim retorne as 5 primeiras linhas do dataset e mostre os seus dados.

heart_disease_df_va.head()
# Out:
#    age  sex  cp trestbps chol fbs  ...  exang oldpeak slope ca thal target
# 0   44    1   4      130  209   0  ...      0       0     ?  ?    ?      0
# 1   60    1   4      132  218   0  ...      1     1.5     3  ?    ?      2
# 2   55    1   4      142  228   0  ...      1     2.5     1  ?    ?      1
# 3   66    1   3      110  213   1  ...      1     1.3     2  ?    ?      0
# 4   66    1   3      120    0   0  ...      0    -0.5     1  ?    ?      0
#
# [5 rows x 14 columns]

# %%
#Normalização das tabelas

heart_disease_df_va['age'] = heart_disease_df_va['age'].apply(lambda x: None if x == '?' else x) 
heart_disease_df_va['sex'] = heart_disease_df_va['sex'].apply(lambda x: None if x == '?' else x)
heart_disease_df_va['cp'] = heart_disease_df_va['cp'].apply(lambda x: None if x == '?' else x)
heart_disease_df_va['trestbps'] = heart_disease_df_va['trestbps'].apply(lambda x: None if x == '?' else x)
heart_disease_df_va['chol'] = heart_disease_df_va['chol'].apply(lambda x: None if x == '?' else x)
heart_disease_df_va['fbs'] = heart_disease_df_va['fbs'].apply(lambda x: None if x == '?' else x)
heart_disease_df_va['restecg'] = heart_disease_df_va['restecg'].apply(lambda x: None if x == '?' else x) 
heart_disease_df_va['thalach'] = heart_disease_df_va['thalach'].apply(lambda x: None if x == '?' else x)
heart_disease_df_va['exang'] = heart_disease_df_va['exang'].apply(lambda x: None if x == '?' else x)
heart_disease_df_va['oldpeak'] = heart_disease_df_va['oldpeak'].apply(lambda x: None if x == '?' else x)
heart_disease_df_va['slope'] = heart_disease_df_va['slope'].apply(lambda x: None if x == '?' else x)
heart_disease_df_va['ca'] = heart_disease_df_va['ca'].apply(lambda x: None if x == '?' else x)
heart_disease_df_va['thal'] = heart_disease_df_va['thal'].apply(lambda x: None if x == '?' else x)
heart_disease_df_va['target'] = heart_disease_df_va['target'].apply(lambda x: None if x == '?' else x)

# %%
#Utilização do comando "astype" para pegar o determinado valor e converter ele para float

heart_disease_df_va['cp']= heart_disease_df_va['cp'].astype(float)
heart_disease_df_va['trestbps']= heart_disease_df_va['trestbps'].astype(float)
heart_disease_df_va['chol']= heart_disease_df_va['chol'].astype(float)
heart_disease_df_va['fbs']= heart_disease_df_va['fbs'].astype(float)
heart_disease_df_va['restecg']= heart_disease_df_va['restecg'].astype(float)
heart_disease_df_va['thalach']= heart_disease_df_va['thalach'].astype(float)
heart_disease_df_va['exang']= heart_disease_df_va['exang'].astype(float)
heart_disease_df_va['oldpeak']= heart_disease_df_va['oldpeak'].astype(float)
heart_disease_df_va['slope']= heart_disease_df_va['slope'].astype(float)
heart_disease_df_va['oldpeak']= heart_disease_df_va['oldpeak'].astype(float)
heart_disease_df_va['ca']= heart_disease_df_va['ca'].astype(float)
heart_disease_df_va['thal']=heart_disease_df_va['thal'].astype(float)

# %%
#Utilização do comando "astype" para pegar o determinado valor e converter ele para object

heart_disease_df_va['ca']= heart_disease_df_va['ca'].astype(object)
heart_disease_df_va['thal']= heart_disease_df_va['thal'].astype(object)

# %%
heart_disease_df_va['target'] =  heart_disease_df_va.target.replace([1,2,3,4],['yes','yes','yes','yes'])
heart_disease_df_va['target'] =  heart_disease_df_va.target.replace([0],['no'])

# %%
heart_disease_df_va['sex'] =  heart_disease_df_va.sex.replace([0.,1],['female','male'])

# %%
#Retornando os dados com os alguns valores deles convertidos

heart_disease_df_va.head()
# Out:
#    age   sex   cp  trestbps   chol  fbs  ...  exang  oldpeak  slope   ca  thal target
# 0   44  male  4.0     130.0  209.0  0.0  ...    0.0      0.0    NaN  NaN   NaN     no
# 1   60  male  4.0     132.0  218.0  0.0  ...    1.0      1.5    3.0  NaN   NaN    yes
# 2   55  male  4.0     142.0  228.0  0.0  ...    1.0      2.5    1.0  NaN   NaN    yes
# 3   66  male  3.0     110.0  213.0  1.0  ...    1.0      1.3    2.0  NaN   NaN     no
# 4   66  male  3.0     120.0    0.0  0.0  ...    0.0     -0.5    1.0  NaN   NaN     no
#
# [5 rows x 14 columns]

# %%
#Usando o comando describe(), onde vai retornar alguns dados importantes da tabela como a média, padrão, valor min, valor maximo... vizualizando e analisando alguns dados estatístico

heart_disease_df_va.describe()

# %%
#Utilizando a função info(), para que assim demonstre uma visão geral do nosso dataset

heart_disease_df_va.info()

# %%
#Função isnull().sum() para descobri os dados faltantes

heart_disease_df_va.isnull().sum()
# Out:
# age           0
# sex           0
# cp            0
# trestbps     56
# chol          7
# fbs           7
# restecg       0
# thalach      53
# exang        53
# oldpeak      56
# slope       102
# ca          197
# thal        165
# target        0
# dtype: int64

# %%
# Cáculo da porcentagem dos dados nulos

(heart_disease_df_va.isnull().sum() / len(heart_disease_df_va['age']))*100
# Out:
# age          0.000000
# sex          0.000000
# cp           0.000000
# trestbps    28.140704
# chol         3.517588
# fbs          3.517588
# restecg      0.000000
# thalach     26.633166
# exang       26.633166
# oldpeak     28.140704
# slope       51.256281
# ca          98.994975
# thal        82.914573
# target       0.000000
# dtype: float64

# %%
# Retirar as colunas do dataset
del heart_disease_df_va['slope']
del heart_disease_df_va['ca']
del heart_disease_df_va['thal']

# %%
#Usando a função round() para arredondar os valores das casas decimais do dataset

heart_disease_df_va.round()
# Out:
#      age     sex   cp  trestbps   chol  ...  restecg  thalach  exang  oldpeak  target
# 0     44    male  4.0     130.0  209.0  ...      1.0    127.0    0.0      0.0      no
# 1     60    male  4.0     132.0  218.0  ...      1.0    140.0    1.0      2.0     yes
# 2     55    male  4.0     142.0  228.0  ...      1.0    149.0    1.0      2.0     yes
# 3     66    male  3.0     110.0  213.0  ...      2.0     99.0    1.0      1.0      no
# 4     66    male  3.0     120.0    0.0  ...      1.0    120.0    0.0     -0.0      no
# ..   ...     ...  ...       ...    ...  ...      ...      ...    ...      ...     ...
# 194   54  female  4.0     127.0  333.0  ...      1.0    154.0    0.0      0.0     yes
# 195   62    male  1.0       NaN  139.0  ...      1.0      NaN    NaN      NaN      no
# 196   55    male  4.0     122.0  223.0  ...      1.0    100.0    0.0      0.0     yes
# 197   58    male  4.0       NaN  385.0  ...      2.0      NaN    NaN      NaN      no
# ...

# %%
#Utilização do comando count para demonstrar a quantidade de cada variável

heart_disease_df_va.groupby('sex')['sex'].count()
# Out:
# sex
# female      6
# male      193
# Name: sex, dtype: int64

# %%
#Criação de um gráfico de pizza para que possamos analisar 

labels='Feminino','Masculino'
size =[3.01,96.98]
color_list = ['pink','lightblue']
figl, axl = plt.subplots()
axl.pie(size,labels=labels,shadow = True,autopct='%1.1f%%', startangle = 90,colors=color_list)
axl.axis('equal')
axl.set_title('Quantidade de indivíduos com doenças cardíacas divididos por sexo',fontsize = 14)
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Grafico em barra demonstrando a média de idade de acordo com cada sexo

media_sex1=heart_disease_df_va['age'].loc[heart_disease_df_va['sex']=='male'].mean()
media_sex0 = heart_disease_df_va['age'].loc[heart_disease_df_va['sex']=='female'].mean()
plt.title('Média de idades do sexo 0 e sexo 1')
plt.bar('Feminino',media_sex0,color='pink')
plt.bar('Masculino',media_sex1,color='lightblue')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Hist() relação idade e sexo feminino
heart_disease_df_va['age'].loc[heart_disease_df_va['sex']=='female'].hist()
plt.title('Histograma Sexo feminino x idade')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#hist() sobre relação idade e sexo masculino
heart_disease_df_va['age'].loc[heart_disease_df_va['sex']=='male'].hist()
plt.title('Histograma Sexo masculino x idade')
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
# Hist() sobre relação de idade e a presença de doenças do coração
heart_disease_df_va['age'].loc[heart_disease_df_va['exang']==0].hist()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.title("Relação de idade e a presença de doenças do coração")
plt.show()

# %%
# Hist() sobre relação de idade e a presença de doenças do coração
heart_disease_df_va['age'].loc[heart_disease_df_va['exang']==1].hist()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.title("Relação de idade e a presença de doenças do coração")
plt.show()

# %%
#Grafico em linhas demonstrando os batimentos cadiarcos de acordo com cada sexo

plt.plot(heart_disease_df_va['trestbps'].loc[heart_disease_df_va['sex']==0],label = 'Batimentos de pessoas do sexo 0(F)')
plt.plot(heart_disease_df_va['trestbps'].loc[heart_disease_df_va['sex']==1],label = 'Batimentos de pessoas do sexo 1(M)')
plt.legend()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Utilização do comando count para demonstrar a quantidade de cada variável

heart_disease_df_va.groupby('cp')['cp'].count()

# %%
# Graficos em pizza com o percentual dos tipos de dores no peito mais relatados

labels= 'angina típica','angina atípica','dor não anginosa','assitomático'
size =[7.03,4.02,23.6,65.35]
color_list = ['blue','yellow','green','red']
figl, axl = plt.subplots()
axl.pie(size,labels=labels,shadow = True,autopct='%1.1f%%', startangle = 90,colors=color_list)
axl.axis('equal')
axl.set_title('Porcentagem de individuos e suas respectivas dores no peito',fontsize = 14)
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Utilização do comando count para demonstrar a quantidade de cada variável
heart_disease_df_va.groupby('exang')['exang'].count()

# %%
# Graficos em pizza com o percentual da relação de angina positiva e negativa
labels='Angina negativa','Angina positiva'
size =[52,94]
color_list = ['green','red']
figl, axl = plt.subplots()
axl.pie(size,labels=labels,shadow = True,autopct='%1.1f%%', startangle = 90,colors=color_list)
axl.axis('equal')
axl.set_title('Indivíduos com angina positiva e negativa',fontsize = 14)
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
#Utilização do comando count para demonstrar a quantidade de cada variável
heart_disease_df_va.groupby('fbs')['fbs'].count()

# %%
#Utilização do grafico de pizza para mostrar a relação do áçucar positivo e negativo
labels='Açucar no sangue positivo','Açucar no sangue negativo'
size =[124,68]
color_list = ['blue','orange']
figl, axl = plt.subplots()
axl.pie(size,labels=labels,shadow = True,autopct='%1.1f%%', startangle = 90,colors=color_list)
axl.axis('equal')
axl.set_title('Indivíduos com açucar no sangue positivo e negativo',fontsize = 14)
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()

# %%
# hist() sobre relação entre sexo masculino e presença de doenças do coração
heart_disease_df_va['target'].loc[heart_disease_df_va['sex']=='male'].hist()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.tilte("Relação entre sexo masculino e presença de doenças do coração")
plt.show()

# %%
# hist() sobre relação entre sexo feminino e presença de doenças do coração
heart_disease_df_va['target'].loc[heart_disease_df_va['sex']=='female'].hist()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.title("Relação entre sexo  e presença de doenças do coração")
plt.show()

# %%
# hist() sobre relação entre idade e presença de doenças do coração
heart_disease_df_va['age'].loc[heart_disease_df_va['target']=='yes'].hist()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.title("Relação entre idade e presença de doenças do coração")
plt.show()

# %%
# hist() sobre relação entre idade e não presença de doenças do coração
heart_disease_df_va['age'].loc[heart_disease_df_va['target']=='no'].hist()
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.title("Relação entre idade e não presença de doenças do coração")
plt.show()

# %%
#Utilizando a função sns.heatmap para que plote os dados e gere uma matriz de correlação 

plt.figure(figsize=(10,10))
sns.heatmap(heart_disease_df_va.corr(),annot= True,cmap='YlGn' ,vmin = -1, vmax = 1)
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.show()
